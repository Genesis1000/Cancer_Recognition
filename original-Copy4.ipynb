# %%
from PyQt5 import QtCore, QtGui, QtWidgets
class Ui_Dialog(object):
    def setupUi(self, Dialog):
        Dialog.setObjectName("Dialog")
        Dialog.resize(665, 239)
        Dialog.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 18pt \"Lucida Handwriting\";\n"
"background-image: url(:/newPrefix/alv.png);")
        self.selectImageBtn = QtWidgets.QPushButton(Dialog)
        self.selectImageBtn.setGeometry(QtCore.QRect(10, 70, 241, 51))
        font = QtGui.QFont()
        font.setFamily("Lucida Handwriting")
        font.setPointSize(18)
        font.setBold(False)
        font.setItalic(False)
        font.setWeight(50)
        self.selectImageBtn.setFont(font)
        self.selectImageBtn.setStyleSheet("border-color: rgb(238, 238, 238);")
        self.selectImageBtn.setObjectName("selectImageBtn")
        self.imageLbl = QtWidgets.QLabel(Dialog)
        self.imageLbl.setGeometry(QtCore.QRect(260, 70, 151, 101))
        self.imageLbl.setFrameShape(QtWidgets.QFrame.Box)
        self.imageLbl.setFrameShadow(QtWidgets.QFrame.Plain)
        self.imageLbl.setText("")
        self.imageLbl.setObjectName("imageLbl")
        self.addBtn = QtWidgets.QPushButton(Dialog)
        self.addBtn.setGeometry(QtCore.QRect(10, 180, 241, 41))
        self.addBtn.setObjectName("addBtn")
        self.titlelabel = QtWidgets.QLabel(Dialog)
        self.titlelabel.setGeometry(QtCore.QRect(190, 0, 261, 41))
        self.titlelabel.setStyleSheet("background-color: rgb(235, 235, 235);")
        self.titlelabel.setObjectName("titlelabel")
        self.predict = QtWidgets.QPushButton(Dialog)
        self.predict.setGeometry(QtCore.QRect(10, 130, 241, 41))
        self.predict.setObjectName("predict")
        pixmap = QtGui.QPixmap('bg.png') 
        self.logo = QtWidgets.QLabel(Dialog)
        pixmap = pixmap.scaled(self.logo.width(), self.logo.height(), QtCore.Qt.KeepAspectRatio) # Scale pixmap

        self.logo.setGeometry(QtCore.QRect(120, 0, 71, 41))
        self.logo.setPixmap(pixmap)
        self.logo.setAlignment(QtCore.Qt.AlignCenter)

        self.logo.setText("")
        self.logo.setObjectName("logo")
        self.predicttext = QtWidgets.QLabel(Dialog)
        self.predicttext.setGeometry(QtCore.QRect(260, 180, 151, 41))
        
        self.predicttext.setText("")
        self.predicttext.setObjectName("predicttext")

        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)

    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "Dialog"))
        self.selectImageBtn.setText(_translate("Dialog", "Select Image"))
        self.addBtn.setText(_translate("Dialog", "Generate Report"))
        self.titlelabel.setText(_translate("Dialog", "HOPE 4 CANCER"))
        self.predict.setText(_translate("Dialog", "Predict"))

import al_rc
import alvi_rc

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Dialog = QtWidgets.QDialog()
    ui = Ui_Dialog()
    ui.setupUi(Dialog)
    Dialog.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\DELL\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from PyQt5 import QtCore, QtGui, QtWidgets
from formupdatedlatestd import Ui_Form
import datetime
now = datetime.datetime.now()

class Ui_Dialog(object):
    def openWindow(self):
        self.window = QtWidgets.QMainWindow()
        self.ui = Ui_Form()
        self.ui.setupUi(self.window)
        Dialog.hide()
        self.window.show()
    def setupUi(self, Dialog):
        Dialog.setObjectName("Dialog")
        Dialog.resize(665, 239)
        Dialog.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 18pt \"Lucida Handwriting\";\n"
"background-image: url(:/newPrefix/alv.png);")
        self.selectImageBtn = QtWidgets.QPushButton(Dialog)
        self.selectImageBtn.setGeometry(QtCore.QRect(10, 70, 241, 51))
        font = QtGui.QFont()
        font.setFamily("Lucida Handwriting")
        font.setPointSize(18)
        font.setBold(False)
        font.setItalic(False)
        font.setWeight(50)
        self.selectImageBtn.setFont(font)
        self.selectImageBtn.setStyleSheet("border-color: rgb(238, 238, 238);")
        self.selectImageBtn.setObjectName("selectImageBtn")
        self.imageLbl = QtWidgets.QLabel(Dialog)
        self.imageLbl.setGeometry(QtCore.QRect(260, 70, 151, 101))
        self.imageLbl.setFrameShape(QtWidgets.QFrame.Box)
        self.imageLbl.setFrameShadow(QtWidgets.QFrame.Plain)
        self.imageLbl.setText("")
        self.imageLbl.setObjectName("imageLbl")
        self.addBtn = QtWidgets.QPushButton(Dialog)
        self.addBtn.setGeometry(QtCore.QRect(10, 180, 241, 41))
        self.addBtn.setObjectName("addBtn")
        self.titlelabel = QtWidgets.QLabel(Dialog)
        self.titlelabel.setGeometry(QtCore.QRect(190, 0, 261, 41))
        self.titlelabel.setStyleSheet("background-color: rgb(235, 235, 235);")
        self.titlelabel.setObjectName("titlelabel")
        self.predict = QtWidgets.QPushButton(Dialog)
        self.predict.setGeometry(QtCore.QRect(10, 130, 241, 41))
        self.predict.setObjectName("predict")
        pixmap = QtGui.QPixmap('bg.png') 
        self.logo = QtWidgets.QLabel(Dialog)
        pixmap = pixmap.scaled(self.logo.width(), self.logo.height(), QtCore.Qt.KeepAspectRatio) # Scale pixmap

        self.logo.setGeometry(QtCore.QRect(120, 0, 71, 41))
        self.logo.setPixmap(pixmap)
        self.logo.setAlignment(QtCore.Qt.AlignCenter)

        self.logo.setText("")
        self.logo.setObjectName("logo")
        self.predicttext = QtWidgets.QLabel(Dialog)
        self.predicttext.setGeometry(QtCore.QRect(260, 180, 151, 41))
        
        self.predicttext.setText("")
        self.predicttext.setObjectName("predicttext")

        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)
        self.addBtn.clicked.connect(self.openWindow)


    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "HOPE 4 CANCER"))
        self.selectImageBtn.setText(_translate("Dialog", "Select Image"))
        self.addBtn.setText(_translate("Dialog", "Generate Report"))
        self.titlelabel.setText(_translate("Dialog", "HOPE 4 CANCER"))
        self.predict.setText(_translate("Dialog", "Predict"))

import al_rc
import alvi_rc

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Dialog = QtWidgets.QDialog()
    ui = Ui_Dialog()
    ui.setupUi(Dialog)
    Dialog.show()
    sys.exit(app.exec_())

# %%
from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(709, 555)
        Form.setStyleSheet("background-image: url(:/newPrefix/ennr.png);\n"
"\n"
"font: 16pt \"Lucida Handwriting\";")
        self.title = QtWidgets.QLabel(Form)
        self.title.setGeometry(QtCore.QRect(240, 10, 191, 51))
        self.title.setObjectName("title")
        pixmap = QtGui.QPixmap('bg.png')
        self.logodisplay = QtWidgets.QLabel(Form)
        pixmap = pixmap.scaled(self.logodisplay.width(), self.logodisplay.height(), QtCore.Qt.KeepAspectRatio) # Scale pixmap

        self.logodisplay.setGeometry(QtCore.QRect(170, 10, 61, 51))
        self.logodisplay.setPixmap(pixmap)
        self.logodisplay.setAlignment(QtCore.Qt.AlignCenter)
        self.logodisplay.setText("")
        self.logodisplay.setObjectName("logodisplay")
        self.name = QtWidgets.QLabel(Form)
        self.name.setGeometry(QtCore.QRect(40, 100, 111, 51))
        self.name.setObjectName("name")
        self.nametext = QtWidgets.QLineEdit(Form)
        self.nametext.setGeometry(QtCore.QRect(150, 100, 451, 51))
        self.nametext.setObjectName("nametext")
        self.age = QtWidgets.QLabel(Form)
        self.age.setGeometry(QtCore.QRect(40, 180, 101, 51))
        self.age.setObjectName("age")
        self.agetext = QtWidgets.QLineEdit(Form)
        self.agetext.setGeometry(QtCore.QRect(140, 180, 461, 51))
        self.agetext.setObjectName("agetext")
        self.dob = QtWidgets.QLabel(Form)
        self.dob.setGeometry(QtCore.QRect(40, 260, 111, 51))
        self.dob.setObjectName("dob")
        self.dobtext = QtWidgets.QDateEdit(Form)
        self.dobtext.setGeometry(QtCore.QRect(150, 260, 451, 51))
        self.dobtext.setDateTime(QtCore.QDateTime(QtCore.QDate(1950, 1, 1), QtCore.QTime(0, 0, 0)))
        self.dobtext.setObjectName("dobtext")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(40, 340, 111, 51))
        self.label.setObjectName("label")
        self.dateEdit = QtWidgets.QDateEdit(Form)
        self.dateEdit.setGeometry(QtCore.QRect(150, 340, 451, 51))
        self.dateEdit.setDateTime(QtCore.QDateTime(QtCore.QDate(2019, 1, 4), QtCore.QTime(0, 0, 0)))
        self.dateEdit.setObjectName("dateEdit")
        self.genreportpdf = QtWidgets.QPushButton(Form)
        self.genreportpdf.setGeometry(QtCore.QRect(200, 480, 291, 61))
        self.genreportpdf.setObjectName("genreportpdf")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(40, 410, 111, 51))
        self.label_2.setObjectName("label_2")
        self.lineEdit = QtWidgets.QLineEdit(Form)
        self.lineEdit.setGeometry(QtCore.QRect(150, 410, 451, 51))
        self.lineEdit.setObjectName("lineEdit")

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.title.setText(_translate("Form", "HOPE 4 CANCER"))
        self.name.setText(_translate("Form", "Name:"))
        self.age.setText(_translate("Form", "Age:"))
        self.dob.setText(_translate("Form", "DOB:"))
        self.label.setText(_translate("Form", "Date:"))
        self.genreportpdf.setText(_translate("Form", "Generate Report"))
        self.label_2.setText(_translate("Form", "Gender"))

import alvi_rc

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\alvin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3304: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from PyQt5 import QtCore, QtGui, QtWidgets
from formupdatedlatestd import Ui_Form
import matplotlib.pyplot as plt
import matplotlib.image as mpimgv
import matplotlib.pyplot as plt
import cv2
import re
from docx import Document
from docx.shared import Inches
from keras.models import Model # basic class for specifying and training a neural network
from keras.layers import Input, Convolution2D, MaxPooling2D, Dense, Dropout, Activation, Flatten
from keras.utils import np_utils # utilities for one-hot encoding of ground truth values
import numpy as np
import glob
import re
import os
from playsound import playsound
from docx import Document
from docx.shared import Inches
import datetime
now = datetime.datetime.now()
#import simpleaudio as sa
import numpy as np
from PIL import  ImageTk,Image
import sqlite3
conn=sqlite3.connect('test1.db')
print("Database connection established")
w,h = 50,50
from keras.models import model_from_json
json_file = open('kidskinbrelunghn1.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("kidskinbrelunghn1.h5")
print("Loaded model from disk")

class Ui_Dialog(object):
    def openWindow(self):
        if self.predicttext.text():
            class Ui_Form(object):
                def setupUi(self, Form):
                    Form.setObjectName("Form")
                    Form.resize(709, 555)
                    Form.setStyleSheet("background-image: url(:/newPrefix/ennr.png);\n"
            "")
                    self.title = QtWidgets.QLabel(Form)
                    self.title.setGeometry(QtCore.QRect(240, 10, 191, 51))
                    self.title.setStyleSheet("font: 16pt \"Lucida Handwriting\";")
                    self.title.setObjectName("title")
                    pixmap = QtGui.QPixmap('bg.png')
                    self.logodisplay = QtWidgets.QLabel(Form)
                    self.logodisplay.setGeometry(QtCore.QRect(170, 10, 61, 51))
                    pixmap = pixmap.scaled(self.logodisplay.width(), self.logodisplay.height(), QtCore.Qt.KeepAspectRatio) # Scale pixmap
                    self.logodisplay.setPixmap(pixmap)
                    self.logodisplay.setText("")
                    self.logodisplay.setObjectName("logodisplay")
                    self.name = QtWidgets.QLabel(Form)
                    self.name.setGeometry(QtCore.QRect(40, 110, 101, 41))
                    self.name.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.name.setObjectName("name")
                    self.nametext = QtWidgets.QLineEdit(Form)
                    self.nametext.setGeometry(QtCore.QRect(140, 110, 301, 41))
                    self.nametext.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.nametext.setObjectName("nametext")
                    self.age = QtWidgets.QLabel(Form)
                    self.age.setGeometry(QtCore.QRect(40, 180, 111, 41))
                    self.age.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.age.setObjectName("age")
                    self.agetext = QtWidgets.QLineEdit(Form)
                    self.agetext.setGeometry(QtCore.QRect(150, 180, 301, 41))
                    self.agetext.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.agetext.setObjectName("agetext")
                    self.dob = QtWidgets.QLabel(Form)
                    self.dob.setGeometry(QtCore.QRect(40, 250, 111, 41))
                    self.dob.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.dob.setObjectName("dob")
                    self.dobtext = QtWidgets.QDateEdit(Form)
                    self.dobtext.setGeometry(QtCore.QRect(150, 250, 301, 41))
                    self.dobtext.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.dobtext.setDateTime(QtCore.QDateTime(QtCore.QDate(1950, 1, 1), QtCore.QTime(0, 0, 0)))
                    self.dobtext.setObjectName("dobtext")
                    self.label = QtWidgets.QLabel(Form)
                    self.label.setGeometry(QtCore.QRect(40, 320, 111, 41))
                    self.label.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.label.setObjectName("label")
                    self.dateEdit = QtWidgets.QDateEdit(Form)
                    self.dateEdit.setGeometry(QtCore.QRect(150, 320, 511, 41))
                    self.dateEdit.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.dateEdit.setDateTime(QtCore.QDateTime(QtCore.QDate(now.year, now.day, now.month), QtCore.QTime(0, 0, 0)))
                    self.dateEdit.setObjectName("dateEdit")
                    self.genreportpdf = QtWidgets.QPushButton(Form)
                    self.genreportpdf.setGeometry(QtCore.QRect(200, 480, 291, 61))
                    self.genreportpdf.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.genreportpdf.setObjectName("genreportpdf")
                    self.label_2 = QtWidgets.QLabel(Form)
                    self.label_2.setGeometry(QtCore.QRect(40, 390, 111, 41))
                    self.label_2.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.label_2.setObjectName("label_2")
                    self.lineEdit = QtWidgets.QLineEdit(Form)
                    self.lineEdit.setGeometry(QtCore.QRect(150, 390, 511, 41))
                    self.lineEdit.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.lineEdit.setObjectName("lineEdit")
                    self.label_3 = QtWidgets.QLabel(Form)
                    self.label_3.setGeometry(QtCore.QRect(490, 100, 131, 121))
                    self.label_3.setText("")
                    self.label_3.setObjectName("label_3")
                    pixmap = QtGui.QPixmap("F:/hope/s.png") # Setup pixmap with the provided image
                    pixmap = pixmap.scaled(self.label_3.width(), self.label_3.height(), QtCore.Qt.KeepAspectRatio) # Scale pixmap
                    self.label_3.setPixmap(pixmap)
                    self.pushButton = QtWidgets.QPushButton(Form)
                    self.pushButton.setGeometry(QtCore.QRect(460, 230, 201, 31))
                    self.pushButton.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.pushButton.setObjectName("pushButton")
                    self.pushButton_2 = QtWidgets.QPushButton(Form)
                    self.pushButton_2.setGeometry(QtCore.QRect(460, 270, 201, 31))
                    self.pushButton_2.setStyleSheet("font: 12pt \"Lucida Handwriting\";")
                    self.pushButton_2.setObjectName("pushButton_2")
                    self.retranslateUi(Form)
                    QtCore.QMetaObject.connectSlotsByName(Form)
                    self.genreportpdf.clicked.connect(self.setImage1)
                    self.pushButton.clicked.connect(self.camfunction)
                    self.pushButton_2.clicked.connect(self.setImage2)

                def retranslateUi(self, Form):
                    _translate = QtCore.QCoreApplication.translate
                    Form.setWindowTitle(_translate("Form", "Form"))
                    self.title.setText(_translate("Form", "HOPE 4 CANCER"))
                    self.name.setText(_translate("Form", "Name:"))
                    self.age.setText(_translate("Form", "Age:"))
                    self.dob.setText(_translate("Form", "DOB:"))
                    self.label.setText(_translate("Form", "Date:"))
                    self.genreportpdf.setText(_translate("Form", "Generate Report"))
                    self.label_2.setText(_translate("Form", "Gender:"))
                    self.pushButton.setText(_translate("Form", "Use Camera"))
                    self.pushButton_2.setText(_translate("Form", "Browse from Device"))
                def camfunction(self):
                    import cv2
                    import os
                    def assure_path_exists(path):
                        dir = os.path.dirname(path)
                        if not os.path.exists(dir):
                            os.makedirs(dir)

                    vid_cam = cv2.VideoCapture(0)
                    face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
                    assure_path_exists("F:/reports/dataset/")
                    _, image_frame = vid_cam.read()
                    faces = face_detector.detectMultiScale(image_frame, 1.3, 5)
                    for (x,y,w,h) in faces:
                        cv2.rectangle(image_frame, (x,y), (x+w,y+h), (255,0,0), 2)
                        global name
                        name="F:/reports/dataset/User-"+self.nametext.text()+ ".jpg"
                        cv2.imwrite(name, image_frame[y:y+h,x:x+w])
                        cv2.imshow('frame', image_frame)
                        break
                    vid_cam.release()
                    cv2.destroyAllWindows()
                    pixmap = QtGui.QPixmap(name) # Setup pixmap with the provided image
                    pixmap = pixmap.scaled(self.label_3.width(), self.label_3.height(), QtCore.Qt.KeepAspectRatio) # Scale pixmap
                    self.label_3.setPixmap(pixmap)
                def setImage2(self,):
                    global name
                    image, _ = QtWidgets.QFileDialog.getOpenFileName(None, "Select Image", "", "Image Files (*.png *.jpg *jpeg *.bmp)") # Ask for file
                    if image: # If the user gives a file
                        name="F:/reports/dataset/User-"+self.nametext.text()+ ".jpg"
                        pixmap = QtGui.QPixmap(image) # Setup pixmap with the provided image
                        pixmap = pixmap.scaled(self.label_3.width(), self.label_3.height(), QtCore.Qt.KeepAspectRatio) # Scale pixmap
                        self.label_3.setPixmap(pixmap) # Set the pixmap onto the label
                        self.label_3.setAlignment(QtCore.Qt.AlignCenter) # Align the label to center
                        im=cv2.imread(image)
                        cv2.imwrite(name, im)



                def setImage1(self):
                    if self.agetext.text().isdigit() is False and self.agetext.text():
                                playsound('num_age.mp3')
                    def hasNumbers(inputString):
                        return any(char.isdigit() for char in inputString)
                    r=self.nametext.text()
                    s=self.lineEdit.text()
                    r1=hasNumbers(r)
                    s1=hasNumbers(s)
                    if r1:
                        playsound('num_name.mp3')
                    if s1:
                        playsound('num_gender.mp3')
                    if(not r1 and self.agetext.text().isdigit() and self.dobtext.text() and self.dateEdit.text() and not s1):

                        for rows in [(self.nametext.text(),self.agetext.text(),x,self.dateEdit.text())]:
                            conn.execute ('INSERT INTO HOPE (NAME,AGE,TYPE,DATE) VALUES (?,?,?,?)',rows)
                        conn.commit()
                        print("Record created succesfully")
                        conn.close()
                        def docx_replace_regex(doc_obj, regex , replace):

                            for p in doc_obj.paragraphs:
                                if regex.search(p.text):
                                    inline = p.runs
                                    # Loop added to work with runs (strings with same style)
                                    for i in range(len(inline)):
                                        if regex.search(inline[i].text):
                                            text = regex.sub(replace, inline[i].text)
                                            inline[i].text = text

                            for table in doc_obj.tables:
                                for row in table.rows:
                                    for cell in row.cells:
                                        docx_replace_regex(cell, regex , replace)



                        regex1 = re.compile(r"PATIENT")
                        replace1 = self.nametext.text()
                        print(self.lineEdit.text());
                        if (x=="Breast cancer"):
                            filename = "F:/reports/00.docx"
                        elif(x=="kidney cancer"):
                            filename = "F:/reports/01.docx"
                        elif(x=="skin cancer"):
                            filename = "F:/reports/02.docx"
                        elif(x=="lung cancer"):
                            filename = "F:/reports/03.docx"
                        else:
                            filename = "F:/reports/05.docx"
                        doc = Document(filename)
                        docx_replace_regex(doc, regex1 , replace1)
                        regex1 = re.compile(r"68")
                        replace1 = self.agetext.text()
                        docx_replace_regex(doc, regex1 , replace1)
                        regex1 = re.compile(r"05/15/2014")
                        replace1 = self.dobtext.text()
                        docx_replace_regex(doc, regex1 , replace1)
                        regex1 = re.compile(r"TRD")
                        replace1 = self.dateEdit.text()
                        docx_replace_regex(doc, regex1 , replace1)
                        regex1 = re.compile(r"DRD")
                        replace1 = r"Dr.Artificial Intelligence"
                        docx_replace_regex(doc, regex1 , replace1)
                        regex1 = re.compile(r"SVC")
                        replace1 = x
                        docx_replace_regex(doc, regex1 , replace1)
                        regex1 = re.compile(r"GEND")
                        replace1 = self.lineEdit.text()
                        docx_replace_regex(doc, regex1 , replace1)
                        p = doc.add_paragraph()
                        r = p.add_run()
                        filename=sijo
                        im = cv2.imread(filename)
                        im = cv2.resize(im, (150, 150))
                        cv2.imwrite('F:/reports/cancer_img.png', im)
                        r.add_picture('F:/reports/cancer_img.png')
                        try:
                            doc.save('F:/reports/report/'+name[24:-4]+'.docx')
                            playsound('regenerated.mp3')
                        except:
                            doc.save('F:/reports/report/'+self.nametext.text()+'.docx')
                            playsound('bio.mp3')
                            
                    else :
                        s=0
                        if self.nametext.text()=="":
                            playsound('1NO_name.mp3')
                            s=1
                        if self.agetext.text()=="":
                            playsound('1NO_age.mp3')
                            s=1
                        if self.dobtext.text()=="":
                            playsound('1NO_dob.mp3')
                            s=1
                        if self.dateEdit.text()=="":
                            playsound('1NO_date.mp3')
                            s=1
                        if self.lineEdit.text()=="":
                            playsound('1NO_gender.mp3')
                            s=1
                        if s is 1:
                            playsound('empty.mp3')
                            
                        

                    #strin = self.nametext.text() 
                    #print('Your name : ' + strin)
                    #print('Your age : ' + self.agetext.text())
                    #print('Your dob : ' + self.dobtext.text())
        
                    #print('Your address : ' + self.addresstext.text())

                def set(self):
                    self.setImage1()
        else :
            playsound('NO_img.mp3')

        import alvi_rc

        if __name__ == "__main__":
            import sys
            try:
                self.window = QtWidgets.QMainWindow()
                self.ui = Ui_Form()
                self.ui.setupUi(self.window)
                self.window.show()
            except:
                print("")

    def setupUi(self, Dialog):
        Dialog.setObjectName("Dialog")
        Dialog.resize(665, 239)
        Dialog.setStyleSheet("background-color: rgb(255, 255, 255);\n"
    "font: 14pt \"Lucida Handwriting\";\n"
    "background-image: url(:/newPrefix/alv.png);")
        self.selectImageBtn = QtWidgets.QPushButton(Dialog)
        self.selectImageBtn.setGeometry(QtCore.QRect(10, 70, 241, 51))
        font = QtGui.QFont()
        font.setFamily("Lucida Handwriting")
        font.setPointSize(18)
        font.setBold(False)
        font.setItalic(False)
        font.setWeight(50)
        self.selectImageBtn.setFont(font)
        self.selectImageBtn.setStyleSheet("border-color: rgb(238, 238, 238);")
        self.selectImageBtn.setObjectName("selectImageBtn")
        self.imageLbl = QtWidgets.QLabel(Dialog)
        self.imageLbl.setGeometry(QtCore.QRect(260, 70, 151, 101))
        self.imageLbl.setFrameShape(QtWidgets.QFrame.Box)
        self.imageLbl.setFrameShadow(QtWidgets.QFrame.Plain)
        self.imageLbl.setText("")
        self.imageLbl.setObjectName("imageLbl")
        self.camerabtn = QtWidgets.QPushButton(Dialog)
        self.camerabtn.setGeometry(QtCore.QRect(10, 180, 241, 41))
        self.camerabtn.setObjectName("camerabtn")
        self.titlelabel = QtWidgets.QLabel(Dialog)
        self.titlelabel.setGeometry(QtCore.QRect(190, 0, 261, 41))
        self.titlelabel.setStyleSheet("background-color: rgb(235, 235, 235);")
        self.titlelabel.setObjectName("titlelabel")
        self.predict = QtWidgets.QPushButton(Dialog)
        self.predict.setGeometry(QtCore.QRect(10, 130, 241, 41))
        self.predict.setObjectName("predict")
        pixmap = QtGui.QPixmap('bg.png')
        self.logo = QtWidgets.QLabel(Dialog)
        self.logo.setGeometry(QtCore.QRect(120, 0, 71, 41))
        pixmap = pixmap.scaled(self.logo.width(), self.logo.height(), QtCore.Qt.KeepAspectRatio) # Scale pixmap
        self.logo.setPixmap(pixmap)
        self.logo.setText("")
        self.logo.setObjectName("logo")
        self.predicttext = QtWidgets.QLabel(Dialog)
        self.predicttext.setGeometry(QtCore.QRect(260, 180, 151, 41))
        self.predicttext.setFrameShape(QtWidgets.QFrame.Box)
        self.predicttext.setFrameShadow(QtWidgets.QFrame.Plain)
        self.predicttext.setObjectName("predicttext")

        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)
        self.camerabtn.clicked.connect(self.openWindow)
        self.selectImageBtn.clicked.connect(self.setImage)
        self.predict.clicked.connect(self.predict_cancer)



    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "HOPE 4 CANCER"))
        self.selectImageBtn.setText(_translate("Dialog", "Select Image"))
        self.camerabtn.setText(_translate("Dialog", "Report"))
        self.titlelabel.setText(_translate("Dialog", "HOPE 4 CANCER"))
        self.predict.setText(_translate("Dialog", "Predict"))
    def predict_cancer(self):
        fileName=sijo
        if fileName: # If the user gives a file
            img = QtGui.QPixmap(fileName)
            # Setup pixmap with the provided image
        img = cv2.imread(fileName)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (w, h)) 
        img = img.astype('float32')
        img /= 255
        print(sijo)
        print(self.predicttext.text())
        img = np.array([img,])
        prediction = model.predict(img)
        thresholded = (prediction>0.3)*1
        global x
        x=""
        if((np.where(thresholded == 1)[1][0])==0):
            x="Breast cancer"
            playsound('common.wav')
            playsound('h4c0.wav')
        elif ((np.where(thresholded == 1)[1][0])==1):
            x="kidney cancer"
            playsound('common.wav')
            playsound('h4c1.wav')
            
        elif ((np.where(thresholded == 1)[1][0])==2):
            x="skin cancer"
            playsound('common.wav')
            playsound('h4c2.wav')
        elif ((np.where(thresholded == 1)[1][0])==3):
            x="lung cancer";
            playsound('common.wav')
            playsound('h4c3.wav')
        else:
            x="H&N Cancer";
            playsound('common.wav')
            playsound('h4c5.wav')
        def docx_replace_regex(doc_obj, regex , replace):

                for p in doc_obj.paragraphs:
                    if regex.search(p.text):
                        inline = p.runs
                        # Loop added to work with runs (strings with same style)
                        for i in range(len(inline)):
                            if regex.search(inline[i].text):
                                text = regex.sub(replace, inline[i].text)
                                inline[i].text = text

                for table in doc_obj.tables:
                    for row in table.rows:
                        for cell in row.cells:
                            docx_replace_regex(cell, regex , replace)
        filename = "F:/reports/2.docx"
        doc = Document(filename)
        regex1 = re.compile(r"SVC")
        replace1 = x
        docx_replace_regex(doc, regex1 , replace1)
        doc.save('F:/reports/result1.docx')
        f = open('F:/reports/result1.docx')
        self.predicttext.setText(x)
        print(self.predicttext.text())
    def setImage(self,):
        fileName, _ = QtWidgets.QFileDialog.getOpenFileName(None, "Select Image", "", "Image Files (*.png *.jpg *jpeg *.bmp)") # Ask for file
        global sijo
        sijo=fileName
        if fileName: # If the user gives a file
            pixmap = QtGui.QPixmap(fileName) # Setup pixmap with the provided image
            pixmap = pixmap.scaled(self.imageLbl.width(), self.imageLbl.height(), QtCore.Qt.KeepAspectRatio) # Scale pixmap
            self.imageLbl.setPixmap(pixmap) # Set the pixmap onto the label
            self.imageLbl.setAlignment(QtCore.Qt.AlignCenter) # Align the label to center



import al_rc
import alvi_rc

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Dialog = QtWidgets.QDialog()
    ui = Ui_Dialog()
    ui.setupUi(Dialog)
    Dialog.show()
    sys.exit(app.exec_())
# Out:
# Using TensorFlow backend.
# Database connection established
# WARNING:tensorflow:From C:\Users\DELL\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\DELL\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Loaded model from disk
# F:/dataset/kidney1308.png
#
# kidney cancer
# F:/dataset/lung155.png
# kidney cancer
# lung cancer
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# ...

# %%
x=''
y=2
if(not x and y):
    print("sijo")
def hasNumbers(inputString):
                           return any(char.isdigit() for char in inputString)
p=hasNumbers("shw4ide")
if(not p and 2 and 6):
    print (p)
else:
    print(" sijo")
# Out:
# sijo
#  sijo

# %%
conn=sqlite3.connect('test1.db')
print("succesfully created ..................")
c = conn.cursor()
# Out:
# succesfully created ..................

# %%
for row in conn.execute('SELECT * FROM HOPE'):
    print (row)
# Out:
# ('shekha', 21, 'H&N Cancer', '1/1/2000')
# ('risa', 21, 'kidney cancer', '1/1/2000')
# ('johns', 22, 'H&N Cancer', '4/8/2019')
# ('stanly', 34, 'kidney cancer', '1/1/2000')
# ('dkwdbwd', 12, 'H&N Cancer', '10/10/2019')
# ('Denim', 22, 'H&N Cancer', '7/11/2019')

# %%
print(conn.execute('SELECT count() FROM HOPE'))
